# %% [markdown]
# <a href="https://colab.research.google.com/github/baaponter/MetNumUN2022II/blob/main/Lab4/Group1SymPyLab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# SymPy’s polynomials

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sympy import Symbol
from sympy import div

x = Symbol('x')

p = x**3 - 8*x**2  + x - 18

p, r = div(p,  x-1)

print(p)
print(r)

p, r = div(p,  x-2)

print(p)
print(r)

p, r = div(p,  x-3)

print(p)
print(r)
# Out:
# x**2 - 7*x - 6
# -24
# x - 5
# -16
# 1
# -2

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
p = 2*x**2 + 6*x - 12

p, r = div(p,  x-3)

print(p)
print(r)
# Out:
# 2*x + 12
# 24

# %% [markdown]
# SymPy’s polynomial simple univariate polynomial factorization

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sympy import Symbol,factor
x = Symbol('x')
factor(7*x**4 - 35*x**3 + 21*x)
# Out:
# 7*x*(x**3 - 5*x**2 + 3)

# %% [markdown]
# SymPy’s solvers

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sympy import Symbol, solveset, Eq
x = Symbol('x')
solveset(Eq(x**4 - 3*x**3  - 21*x**2 + 81*x + 270, 0), x)
# Out:
# FiniteSet(-3, -(27*sqrt(1031) + 918)**(1/3)/3 - 15/(27*sqrt(1031) + 918)**(1/3) + 2, 15/(2*(27*sqrt(1031) + 918)**(1/3)) + 2 + (27*sqrt(1031) + 918)**(1/3)/6 + I*(-15*sqrt(3)/(2*(27*sqrt(1031) + 918)**(1/3)) + sqrt(3)*(27*sqrt(1031) + 918)**(1/3)/6), 15/(2*(27*sqrt(1031) + 918)**(1/3)) + 2 + (27*sqrt(1031) + 918)**(1/3)/6 + I*(-sqrt(3)*(27*sqrt(1031) + 918)**(1/3)/6 + 15*sqrt(3)/(2*(27*sqrt(1031) + 918)**(1/3))))

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sympy import Symbol, solveset, Eq, pi
x = Symbol('x')
solveset(Eq(x**pi + ((2)-pi)*x + (pi) , 0), x)
# Out:
# ConditionSet(x, Eq(x*(2 - pi) + x**pi + pi, 0), Complexes)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sympy import Symbol,factor
x = Symbol('y')
factor( x**4  + 4*x**3 + 8*x**2 - 16*x,domain='GF(2)')
# Out:
# y**4

# %% [markdown]
# SymPy’s Symbolic and Numerical Complex Evaluations

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sympy import symbols, I, N, pi, expand
x1, x2, y1, y2, z1, z2 = symbols("x1 x2 y1 y2 z1 z2", real=True)  
x = z2 + I*x2
y = y2 + I*z1
z = z1 + I*y1

print(x*y*z)
print(expand(x*y*z))
print(expand((x*y)*z))
print(expand(x*(y*z)))

w=N(5/(I), 20)
print('w=',w)
# Out:
# (y2 + I*z1)*(I*x2 + z2)*(I*y1 + z1)
# -x2*y1*y2 - I*x2*y1*z1 + I*x2*y2*z1 - x2*z1**2 + I*y1*y2*z2 - y1*z1*z2 + y2*z1*z2 + I*z1**2*z2
# -x2*y1*y2 - I*x2*y1*z1 + I*x2*y2*z1 - x2*z1**2 + I*y1*y2*z2 - y1*z1*z2 + y2*z1*z2 + I*z1**2*z2
# -x2*y1*y2 - I*x2*y1*z1 + I*x2*y2*z1 - x2*z1**2 + I*y1*y2*z2 - y1*z1*z2 + y2*z1*z2 + I*z1**2*z2
# w= -5.0*I

# %% [markdown]
# Wolfram alpha answers question in natural language

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# SymPy’s integrate

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sympy import Symbol, integrate, sin
x = Symbol('x')
integrate(x**3 +x**5, x)
# Out:
# x**6/6 + x**4/4

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sympy import Symbol, integrate, sin, cos, pi
x = Symbol('x')
integrate(sin(x) * cos(x**2), (x,pi,2*pi))
# Out:
# -sqrt(2)*sqrt(pi)*(-sin(1/4)*fresnelc(sqrt(2)*(-1 + 4*pi)/(2*sqrt(pi))) + cos(1/4)*fresnels(sqrt(2)*(-1 + 4*pi)/(2*sqrt(pi))))/4 - sqrt(2)*sqrt(pi)*(-sin(1/4)*fresnelc(sqrt(2)*(1 + 2*pi)/(2*sqrt(pi))) + cos(1/4)*fresnels(sqrt(2)*(1 + 2*pi)/(2*sqrt(pi))))/4 + sqrt(2)*sqrt(pi)*(-sin(1/4)*fresnelc(sqrt(2)*(-1 + 2*pi)/(2*sqrt(pi))) + cos(1/4)*fresnels(sqrt(2)*(-1 + 2*pi)/(2*sqrt(pi))))/4 + sqrt(2)*sqrt(pi)*(-sin(1/4)*fresnelc(sqrt(2)*(1 + 4*pi)/(2*sqrt(pi))) + cos(1/4)*fresnels(sqrt(2)*(1 + 4*pi)/(2*sqrt(pi))))/4

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sympy import Symbol, integrate, N
x = Symbol('x')
N(integrate(x**2 - x**3**x, (x,1,5)))
# Out:
# Integral(x**2 - x**(3**x), (x, 1, 5))
